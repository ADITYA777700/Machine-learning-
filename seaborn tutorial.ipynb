# %%
import seaborn as sns
var=sns.load_dataset("titanic").head(10)
var
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
import matplotlib.pyplot as plt
sns.lineplot(x="fare",y="who",data=x_1,hue='sex',size=50,style='sex',palette='Accent',
             markers=["o",">"],dashes=False,legend="full")
plt.grid()
plt.title("linear plot")

plt.show()

# %%
order_1=["child","man","woman"]
sns.set(style="darkgrid")
sns.barplot(x="who",y="fare",data=var,hue="class",order=order_1,palette='icefire',
            saturation=10,errcolor="y",errwidth=5,alpha=0.5)
plt.title("bargraph")
plt.show()

# %%
sns.displot(var["fare"],kde=True,color="g")
plt.title("histogram")
plt.show()

# %%
import matplotlib.pyplot as plt
m={"male":"*","female":"^"}
import seaborn as sns
sns.scatterplot(x="fare",y="who",data=var,hue="sex",style="sex",size="sex",sizes=(100,60),
               palette="gist_ncar",alpha=1,markers=m)
plt.title("scatter plot")
plt.show()

# %%
import numpy as np
var=np.linspace(1,20,30).reshape(5,6)
var
# Out:
# array([[ 1.        ,  1.65517241,  2.31034483,  2.96551724,  3.62068966,
#          4.27586207],
#        [ 4.93103448,  5.5862069 ,  6.24137931,  6.89655172,  7.55172414,
#          8.20689655],
#        [ 8.86206897,  9.51724138, 10.17241379, 10.82758621, 11.48275862,
#         12.13793103],
#        [12.79310345, 13.44827586, 14.10344828, 14.75862069, 15.4137931 ,
#         16.06896552],
#        [16.72413793, 17.37931034, 18.03448276, 18.68965517, 19.34482759,
#         20.        ]])

# %%
sns.heatmap(var,vmin=0,vmax=25,cmap="gist_heat",annot=True)
# Out:
# <Axes: >

# %%
import numpy as np
ar=np.array([["a0","a1","a2","a3","a4","a5"],
             ["b0","b1","b2","b3","b4","b5"],
             ["c0","c1","c2","c3","c4","c5"],
             ["d0","d1","d2","d3","d4","d5"],
             ["e0","e1","e2","e3","e4","e5"]])
ar
# Out:
# array([['a0', 'a1', 'a2', 'a3', 'a4', 'a5'],
#        ['b0', 'b1', 'b2', 'b3', 'b4', 'b5'],
#        ['c0', 'c1', 'c2', 'c3', 'c4', 'c5'],
#        ['d0', 'd1', 'd2', 'd3', 'd4', 'd5'],
#        ['e0', 'e1', 'e2', 'e3', 'e4', 'e5']], dtype='<U2')

# %%
y={"fontsize":20,"color":"b"}
v=sns.heatmap(var,vmin=0,vmax=25,cmap="gist_heat",annot=ar,fmt="s",annot_kws=y,linewidth =10,linecolor="g",cbar=False
           ,xticklabels=False,yticklabels=False)
v.set(xlabel="number",ylabel="ws")
sns.set(font_scale=5)
plt.show()
